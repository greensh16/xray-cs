# %% [markdown]
# # Analysis
# Some prose that must be skipped.

# %%
# %matplotlib inline
import xarray as xr
import numpy as np
import scipy.integrate as integrate

# %%
out = None
for i in range(10):
    out = xr.concat([out, ds], dim='time')

# %%
# !pip install nothing
grid = np.zeros((4, 4))

# %%
for k in range(10):
    v, e = integrate.quad(f, 0, k)
